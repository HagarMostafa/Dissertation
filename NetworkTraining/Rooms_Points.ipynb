# %%
import numpy as np

# %%
sample_size = 3000

corridor_width = 1130
corridor_width_r4_r1 = 1250
wall_thickness = 250

room3_width1 = 3690
room3_length = 3210

room4_width = 4165
room4_length = 2975

room2_width = 3700
room2_length = 3210

en_suite_width = 1050
en_suite_length = 2090

room1_width = room4_width
room1_length = room4_length

room1_door_width = 900
room2_door_width = 900
room3_door_width = 900
room4_door_width = 900

# %%
room3_dx = room4_width - room3_width1

room3_start_x= corridor_width + wall_thickness
room3_boundary_x1 = room3_start_x + room3_width1
room3_boundary_x2 = room3_start_x + room4_width

room3_start_y = corridor_width + wall_thickness
room3_boundary_y1 = room3_start_y + en_suite_length + wall_thickness
room3_boundary_y2 = room3_start_y + room3_length

# %%
room4_start_x = room3_start_x
room4_boundary_x = room4_start_x + room4_width

room4_start_y = room3_boundary_y2 + wall_thickness
room4_boundary_y = room4_start_y + room4_length

#room4_door_start_x = room4_boundary_x
#room4_door_boundary_x = room4_door_start_x

#room4_door_start_y = room4_start_y + (room4_length*2/3)
#room4_door_boundary_y = room4_door_start_y + room4_door_width

# %%
room1_start_x = room4_boundary_x + corridor_width_r4_r1 + (wall_thickness*2)
room1_boundary_x = room1_start_x + room1_width

room1_start_y = room4_start_y
room1_boundary_y = room1_start_y + room1_length

#room1_door_start_x = room1_start_x
#room1_door_boundary_x = room1_door_start_x

#room1_door_start_y = room1_start_y + (room1_length*2/3)
#room1_door_boundary_y = room1_door_start_y + room1_door_width

# %%
room2_start_x1 = room3_boundary_x1 + (en_suite_width*2) +(wall_thickness*3)
room2_start_x2 = room3_boundary_x2 + corridor_width_r4_r1 + (wall_thickness*2)
room2_boundary_x = room1_boundary_x
#room2_boundary_x = room2_start_x1 + room2_width

room2_start_y = room3_start_y
room2_boundary_y1 = room3_boundary_y1
room2_boundary_y2 = room2_start_y + room2_length

# %%
print(room2_start_x2, room1_start_x)
# Out:
# 7295 7295

# %%
corridor_r4_r1_start_x = room3_boundary_x2 + wall_thickness
corridor_r4_r1_boundary_x = corridor_r4_r1_start_x + corridor_width_r4_r1

corridor_r4_r1_start_y = room3_boundary_y1
corridor_r4_r1_boundary_y = room4_boundary_y

# %%
print(room4_boundary_x,room4_boundary_y, corridor_r4_r1_start_x)
# Out:
# 5545 7815 5795

# %%
room4_1_start_x = room4_boundary_x
room4_1_boundary_x =  room4_1_start_x + corridor_width_r4_r1 + (wall_thickness*2)

room4_1_start_y = room4_start_y + (room4_length*2/3)
room4_1_boundary_y = room4_1_start_y + room4_door_width

# %%
x3_1 = np.random.uniform(low=room3_start_x , high=room3_boundary_x1, size=(int(sample_size*2/3))).astype(int)
y3_1 = np.random.uniform(low=room3_start_y, high=room3_boundary_y1, size=(int(sample_size*2/3))).astype(int)

x3_2 = np.random.uniform(low=room3_start_x , high=room3_boundary_x2, size=(int(sample_size*1/3))).astype(int)
y3_2 = np.random.uniform(low=room3_boundary_y1, high=room3_boundary_y2, size=(int(sample_size*1/3))).astype(int)

# x3_3 = np.random.uniform(low=room3_boundary_x2, high=corridor_r4_r1_start_x, size=(50)).astype(int)
# y3_3 = np.random.uniform(low=room3_boundary_y2-((room3_door_width/2)), high=room3_boundary_y2-((room3_door_width/2)), size=(50)).astype(int)

# %%
x4_1 = np.random.uniform(low=room4_start_x , high=room4_boundary_x, size=(sample_size)).astype(int)
y4_1 = np.random.uniform(low=room4_start_y, high=room4_boundary_y, size=(sample_size)).astype(int)

# x4_2 = np.random.uniform(low=room4_boundary_x, high=corridor_r4_r1_start_x, size=(50)).astype(int)
# y4_2 = np.random.uniform(low=room4_boundary_y-((room4_door_width/2)), high=room4_boundary_y-((room4_door_width/2)), size=(50)).astype(int)

# %%
x1_1 = np.random.uniform(low=room1_start_x , high=room1_boundary_x, size=(sample_size)).astype(int)
y1_1 = np.random.uniform(low=room1_start_y, high=room1_boundary_y, size=(sample_size)).astype(int)

# x1_2 = np.random.uniform(low=corridor_r4_r1_boundary_x , high=room1_start_x, size=(50)).astype(int)
# y1_2 = np.random.uniform(low=room4_boundary_y-((room4_door_width/2)), high=room4_boundary_y-((room4_door_width/2)), size=(50)).astype(int)

# %%
x2_1 = np.random.uniform(low=room2_start_x1 , high=room2_boundary_x, size=(int(sample_size*2/3))).astype(int)
y2_1 = np.random.uniform(low=room2_start_y, high=room2_boundary_y1, size=(int(sample_size*2/3))).astype(int)

x2_2 = np.random.uniform(low=room2_start_x2 , high=room2_boundary_x, size=(int(sample_size*1/3))).astype(int)
y2_2 = np.random.uniform(low=room2_boundary_y1, high=room2_boundary_y2, size=(int(sample_size*1/3))).astype(int)

# x2_3 = np.random.uniform(low=corridor_r4_r1_boundary_x , high=room2_start_x2, size=(50)).astype(int)
# y2_3 = np.random.uniform(low=room3_boundary_y2-((room3_door_width/2)), high=room3_boundary_y2-((room3_door_width/2)), size=(50)).astype(int)

# %%
xc = np.random.uniform(low=corridor_r4_r1_start_x , high=corridor_r4_r1_boundary_x, size=(sample_size)).astype(int)
yc = np.random.uniform(low=corridor_r4_r1_start_y, high=corridor_r4_r1_boundary_y, size=(sample_size)).astype(int)

# %%
#x41 = np.random.uniform(low=room4_1_start_x-wall_thickness , high=room4_1_boundary_x+wall_thickness, size=(sample_size)).astype(int)
#y41 = np.random.uniform(low=room4_1_start_y, high=room4_1_boundary_y, size=(sample_size)).astype(int)

# %%
print(room3_boundary_x2,corridor_r4_r1_start_x,room3_boundary_y2-((room3_door_width/2)),room3_boundary_y2-((room3_door_width/2)))
# Out:
# 5545 5795 4140.0 4140.0

# %%
print(corridor_r4_r1_boundary_x,room1_start_x,room1_boundary_y-((room1_door_width/2)),room1_boundary_y-((room1_door_width/2)))
# Out:
# 7045 7295 7365.0 7365.0

# %%
f3= open("room3.txt","w")
for i in range(int(sample_size*2/3)):
    f3.write(str(x3_1[i])+' '+str(y3_1[i])+'\n')
for i in range(int(sample_size*1/3)):
    f3.write(str(x3_2[i])+' '+str(y3_2[i])+'\n')
# for i in range(50):
#     f3.write(str(x3_3[i])+' '+str(y3_3[i])+'\n')
f3.close()

# %%
f4= open("room4.txt","w")
for i in range(sample_size):
    f4.write(str(x4_1[i])+' '+str(y4_1[i])+'\n')
# for i in range(50):
#     f4.write(str(x4_2[i])+' '+str(y4_2[i])+'\n')
f4.close()

# %%
f1= open("room1.txt","w")
for i in range(sample_size):
    f1.write(str(x1_1[i])+' '+str(y1_1[i])+'\n')
# for i in range(50):
#     f1.write(str(x1_2[i])+' '+str(y1_2[i])+'\n')
f1.close()

# %%
f2= open("room2.txt","w")
for i in range(int(sample_size*2/3)):
    f2.write(str(x2_1[i])+' '+str(y2_1[i])+'\n')
for i in range(int(sample_size*1/3)):
    f2.write(str(x2_2[i])+' '+str(y2_2[i])+'\n')
# for i in range(50):
#     f2.write(str(x2_3[i])+' '+str(y2_3[i])+'\n')
f2.close()

# %%
fc= open("corridor.txt","w")
for i in range(sample_size):
    fc.write(str(xc41[i])+' '+str(yc41[i])+'\n')
# for i in range(50):
#     fc41.write(str(x3_3[i])+' '+str(y3_3[i])+'\n')
# for i in range(50):
#     fc41.write(str(x4_2[i])+' '+str(y4_2[i])+'\n')
# for i in range(50):
#     fc41.write(str(x1_2[i])+' '+str(y1_2[i])+'\n')
# for i in range(50):
#     fc41.write(str(x2_3[i])+' '+str(y2_3[i])+'\n')
fc.close()

# %%
#f41= open("room4_1.txt","w")
#for i in range(300):
#    f41.write(str(x41[i])+' '+str(y41[i])+'\n')
#f41.close()

# %%
# Python program for the above approach
import math
import random
PI = 3.141592653589;
fr= open("reception.txt","w");

class pair:

	def __init__(self, first, second):
		self.first = first;
		self.second = second;

# Return a random between 0 & 1
def uniform():
	return random.random();

# Function to find the N random points on
# the given circle
def randPoint(r, x, y, n):

	# Result vector
	res = list();

	for i in range(n):
		# Get Angle in radians
		theta = 2 * PI * uniform();

		# Get length from center
		len = math.sqrt(uniform()) * r;

		# Add point to results.
		res.append(pair((x + len * math.cos(theta)), (y + len * math.sin(theta))));

	# Return the N points
	return res;

# Function to display the content of
# the vector A
def printVector(A):

	# Iterate over A
	for P in A:
		# Print the N random points stored
		print("({0:.2f}".format(P.first),", ","{0:.2f})".format(P.second));

    
def printFile(A):

	# Iterate over A
    
	for P in A:
		# Print the N random points stored
		fr.write(str(P.first)+" "+str(P.second)+"\n");
    
            
        
# Driver Code
if __name__ == '__main__':
	# Given dimensions
	R = 1800;
	X = 6400;
	Y = 10200;
	N = sample_size;

	# Function call
	printVector(randPoint(R, X, Y, N));
    


# This code is contributed by 29AjayKumar
# Out:
# (4728.74 ,  9880.44)
# (7181.78 ,  8888.41)
# (7297.86 ,  10939.92)
# (5310.61 ,  9524.80)
# (7330.94 ,  9292.60)
# (6578.20 ,  8669.02)
# (7153.03 ,  9799.13)
# (6161.43 ,  9594.46)
# (5551.50 ,  8778.80)
# (6490.42 ,  11531.53)
# (6354.74 ,  8864.01)
# (5413.12 ,  9274.61)
# (6594.39 ,  8835.09)
# (5150.98 ,  9237.40)
# (7395.44 ,  10423.46)
# (6296.92 ,  11846.64)
# (7059.04 ,  11694.52)
# (6781.41 ,  11370.61)
# (7042.35 ,  10919.28)
# (5822.22 ,  8634.11)
# (7354.56 ,  10013.51)
# (6037.36 ,  8456.78)
# (6024.39 ,  10317.76)
# (6838.46 ,  9161.59)
# (7375.30 ,  11711.86)
# (6619.60 ,  9548.36)
# (5542.86 ,  9972.35)
# (4990.73 ,  9260.39)
# (7092.28 ,  10005.55)
# (6045.80 ,  8615.86)
# (5224.76 ,  10218.67)
# (5726.29 ,  9164.88)
# (7010.76 ,  10393.43)
# (5836.37 ,  10936.41)
# (7233.52 ,  11708.14)
# (6075.79 ,  9801.22)
# (5870.22 ,  9222.97)
# (6987.75 ,  11490.20)
# (6988.72 ,  10038.35)
# (6432.94 ,  9782.28)
# (7341.60 ,  10474.80)
# (7849.90 ,  10521.91)
# ...

# %%
printFile(randPoint(1800, 6400, 10200, 3000));
fr.close();
